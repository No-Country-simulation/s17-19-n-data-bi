# %%
import pandas as pd
from datetime import datetime

# %%
import random

# %%
from textblob import TextBlob

# %%
df_usuarios = pd.read_excel('healthtech.xlsx', sheet_name ='DimUsuarios')

# %%
df = df_usuarios.copy()

# %%
# Convertir los nombres de columnas a minúsculas
df.columns = df.columns.str.lower()

# %%
df = df.iloc[34:]
# Eliminar filas duplicadas basadas en 'identificacion' y 'nombre_completo'
df = df.drop_duplicates(subset=['identificacion'])

# %%
# Eliminar la columna 'nombre_completo'
df = df.drop(columns=['nombre_completo'])

# %%
# Crear listas de nombres y apellidos ya proporcionadas
nombres = sorted([
    'Abel', 'Adriana', 'Agustín', 'Alba', 'Alejandro', 'Alicia', 'Amelia', 'Andrés', 'Ángel', 'Antonella',
    'Arturo', 'Beatriz', 'Benjamín', 'Blanca', 'Camila', 'César', 'Clara', 'Cristina', 'Daniel', 'Diana',
    'Diego', 'Dolores', 'Eduardo', 'Elena', 'Emilio', 'Esteban', 'Eugenia', 'Fabio', 'Felipe', 'Fernando',
    'Francisca', 'Gabriel', 'Germán', 'Gloria', 'Gonzalo', 'Guillermo', 'Héctor', 'Hilda', 'Ignacio', 'Inés',
    'Irene', 'Isabel', 'Javier', 'Joaquín', 'Jorge', 'José', 'Juana', 'Julia', 'Julio', 'Laura',
    'Leonardo', 'Lorena', 'Lucas', 'Luis', 'Luz', 'Manuel', 'Marcela', 'Marcos', 'Margarita', 'María',
    'Mariano', 'Marta', 'Matías', 'Mauricio', 'Miguel', 'Mónica', 'Nicolás', 'Nuria', 'Olga', 'Oscar',
    'Pablo', 'Patricia', 'Pedro', 'Pilar', 'Rafael', 'Ramiro', 'Raquel', 'Raúl', 'Ricardo', 'Roberto',
    'Rodrigo', 'Rosa', 'Rubén', 'Salvador', 'Sandra', 'Santiago', 'Sara', 'Sebastián', 'Silvia', 'Sofía',
    'Susana', 'Teresa', 'Tomás', 'Valentina', 'Valeria', 'Verónica', 'Vicente', 'Victoria', 'Ximena', 'Yolanda',
    'Aaron', 'Adela', 'Adrián', 'Aitana', 'Álvaro', 'Amanda', 'Amparo', 'Ana', 'Anabel', 'Antonio',
    'Armando', 'Aurora', 'Avelino', 'Azucena', 'Barbara', 'Braulio', 'Bruno', 'Carla', 'Carlos', 'Carmelo',
    'Cayetano', 'Celia', 'Ciro', 'Clemente', 'Concepción', 'Constanza', 'Cynthia', 'Damián', 'Domingo', 'Edgar',
    'Edmundo', 'Efrén', 'Elías', 'Eloisa', 'Eloy', 'Enrique', 'Ernesto', 'Estela', 'Eulalia', 'Eva',
    'Fabiana', 'Fausto', 'Federico', 'Fernanda', 'Fidel', 'Francisco', 'Gabriela', 'Gerardo', 'Gregorio', 'Guadalupe',
    'Gustavo', 'Héctor', 'Hernán', 'Homero', 'Horacio', 'Hugo', 'Ismael', 'Iván', 'Jacobo', 'Jairo',
    'Jaime', 'Javier', 'Jesús', 'Joaquín', 'Jonathan', 'Jordi', 'José', 'Juan', 'Juana', 'Judith',
    'Justo', 'Karen', 'Karla', 'Katherine', 'Kevin', 'Laura', 'Leandro', 'León', 'Liliana', 'Lina',
    'Lucas', 'Luis', 'Macarena', 'Manuela', 'Marcelo', 'Marcos', 'María', 'Marina', 'Marisol', 'Marta',
    'Martín', 'Mateo', 'Matilde', 'Mercedes', 'Miguel', 'Milagros', 'Miranda', 'Natalia', 'Nelson', 'Nicolás',
    'Noemí', 'Norma', 'Óscar', 'Otilia', 'Pascual', 'Paulina', 'Pedro', 'Priscila', 'Ramón', 'Renata',
    'Ricardo', 'Rigoberto', 'Roberto', 'Rodrigo', 'Rogelio', 'Romina', 'Rosa', 'Rubén', 'Salomé', 'Samuel',
    'Sandra', 'Sara', 'Sebastián', 'Sergio', 'Silvia', 'Sofía', 'Sonia', 'Susana', 'Teresa', 'Tomás',
    'Trinidad', 'Ubaldo', 'Ursula', 'Vanesa', 'Vicente', 'Víctor', 'Virginia', 'Wendy', 'Xavier', 'Yasmina',
    'Yesenia', 'Yolanda', 'Yvette', 'Zacarías', 'Zaira', 'Zulema'
])

apellidos = sorted([
    'Pérez', 'García', 'Rodríguez', 'López', 'Martínez', 'González', 'Hernández', 'Sánchez', 'Ramírez', 'Torres',
    'Flores', 'Rivera', 'Gómez', 'Díaz', 'Vásquez', 'Morales', 'Ortiz', 'Castillo', 'Reyes', 'Ramos',
    'Cruz', 'Romero', 'Mendoza', 'Herrera', 'Medina', 'Aguilar', 'Vega', 'Ibarra', 'Jiménez', 'Navarro',
    'Alonso', 'Álvarez', 'Andrade', 'Arias', 'Barrera', 'Bautista', 'Bravo', 'Campos', 'Carrasco', 'Castro',
    'Cervantes', 'Chávez', 'Cisneros', 'Contreras', 'Correa', 'Cortés', 'Cruz', 'Delgado', 'Domínguez', 'Escobar',
    'Espinoza', 'Estrada', 'Fernández', 'Figueroa', 'Fuentes', 'García', 'Garrido', 'Gil', 'Godoy', 'Gómez',
    'González', 'Guerra', 'Guerrero', 'Gutiérrez', 'Hernández', 'Herrera', 'Ibarra', 'Jiménez', 'Juárez', 'Lara',
    'Lázaro', 'Lima', 'López', 'Luna', 'Macías', 'Maldonado', 'Marín', 'Márquez', 'Martínez', 'Méndez',
    'Miranda', 'Montero', 'Montes', 'Morales', 'Muñoz', 'Nava', 'Nieves', 'Núñez', 'Oliva', 'Ortega',
    'Ortiz', 'Palacios', 'Paredes', 'Patiño', 'Peña', 'Pérez', 'Prieto', 'Ramírez', 'Reyes', 'Rivas',
    'Rivera', 'Robles', 'Rodríguez', 'Rojas', 'Romero', 'Rojas', 'Ruiz', 'Salazar', 'Sánchez', 'Santiago',
    'Santos', 'Sosa', 'Suárez', 'Torres', 'Vargas', 'Vásquez', 'Vega', 'Velasco', 'Velázquez', 'Vera',
    'Vidal', 'Villalobos', 'Zamora', 'Zárate', 'Zúñiga', 'Riquelme', 'Acevedo', 'Barrientos', 'Escalante', 'Quezada',
    'Quintero', 'Delgado', 'Gallardo', 'Gómez', 'López', 'Molina', 'Moreno', 'Rangel', 'Valdez', 'Zavala',
    'Benítez', 'Zaragoza', 'Mancilla', 'Franco', 'Huerta', 'Muñiz', 'Esquivel', 'Villarreal', 'Camacho', 'Aguirre',
    'Ayala', 'Beltrán', 'Bernal', 'Carreón', 'Castañeda', 'Cuenca', 'Guzmán', 'Hurtado', 'León', 'Luque',
    'Montoya', 'Padilla', 'Quintana', 'Ramos', 'Sepúlveda', 'Tirado', 'Uribe', 'Zavala', 'Zepeda', 'Zúñiga'
])

# Generar combinaciones únicas de dos nombres y dos apellidos
combinaciones = set()
while len(combinaciones) < len(df):
    nombre_completo = f"{random.choice(nombres)} {random.choice(nombres)} {random.choice(apellidos)} {random.choice(apellidos)}"
    combinaciones.add(nombre_completo)

# Convertir el set en lista y ordenarlo de A-Z
combinaciones = sorted(list(combinaciones))

# Asignar la lista ordenada a la columna 'nombre_completo'
df['nombre_completo'] = combinaciones

# %%
# Eliminar filas con valores nulos en cualquier columna
df = df.dropna()

# %%
# Verificar si hay valores nulos en todo el DataFrame
nulos_totales = df.isnull().sum()
print(nulos_totales)
# Out:
# identificacion     0
# tipoid             0
# fechanacim         0
# problema           0
# nombre_completo    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 426874 entries, 34 to 427527
# Data columns (total 5 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   identificacion   426874 non-null  object
#  1   tipoid           426874 non-null  object
#  2   fechanacim       426874 non-null  object
#  3   problema         426874 non-null  bool
#  4   nombre_completo  426874 non-null  object
# dtypes: bool(1), object(4)
# memory usage: 16.7+ MB

# %%
# Asegurarse de que 'fechanacim' sea del tipo datetime
df['fechanacim'] = pd.to_datetime(df['fechanacim'], errors='coerce')

# Crear la columna 'edad' calculando la diferencia entre la fecha actual y 'fechanacim'
df['edad'] = df['fechanacim'].apply(lambda x: datetime.now().year - x.year if pd.notnull(x) else None)

# %%
# Reordenar las columnas
df = df[['identificacion', 'tipoid', 'nombre_completo', 'fechanacim', 'edad']]

# %%
# Convertir solo los valores válidos a enteros, ignorando NaN
df['edad'] = df['edad'].apply(lambda x: int(x) if pd.notnull(x) else x)

# %%
# Renombrar la columna 'identificacion' a 'id_paciente'
df = df.rename(columns={'identificacion': 'id_paciente'})

# %%
df.head(50)
# Out:
#    id_paciente tipoid                   nombre_completo fechanacim  edad
# 34  1001799609     TI       Aaron Aaron Escobar Barrera 2001-11-14  23.0
# 35  1001799768     TI         Aaron Aaron Flores Torres 2001-11-17  23.0
# 36  1001799934     TI          Aaron Aaron Franco Ayala 2002-06-20  22.0
# 37  1001800099     CC       Aaron Aaron Hurtado Estrada 1996-11-05  28.0
# 38  1001800288     TI         Aaron Aaron Macías Zavala 2002-06-06  22.0
# 39  1001800485     CC         Aaron Aaron Miranda Ortiz 1999-04-30  25.0
# 40  1001818390     CC       Aaron Aaron Prieto Santiago 1992-05-23  32.0
# 41  1001819404     TI           Aaron Aaron Rojas Bravo 2003-02-17  21.0
# 42  1001820920     CC         Aaron Aaron Tirado Montes 2001-02-13  23.0
# 43  1001822216     TI          Aaron Abel Ayala Vásquez 2003-05-02  21.0
# 44  1001823256     TI          Aaron Abel Benítez Ramos 2003-07-31  21.0
# 45  1001824214     TI        Aaron Abel Delgado Herrera 2002-09-29  22.0
# ...

# %%
df.to_csv('Usuarios.csv', index= False)

# %%
data = pd.read_csv('Data.csv')
# Out:
# /tmp/ipykernel_33842/4238453918.py:1: DtypeWarning: Columns (5,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('Data.csv')

# %%
data.head()
# Out:
#   fecha_transaccion  periodo      id_transaccion  id_sucursal  \
# 0        2024-02-01   202402  281819_281819_1010         1010
# 1        2024-04-26   202404  633315_633315_1017         1017
# 2        2024-02-28   202402  286272_286272_1010         1010
# 3        2024-01-05   202401  251437_251437_1012         1012
# 4        2024-01-17   202401  253375_253375_1012         1012
#
#   linea_dispensacion id_paciente        id_pactprdo    skuagr_2  \
# 0             CAPITA  1002023082  1002023082_202402  61073475G5
# 1             CAPITA    72158665    72158665_202404  16136775G5
# 2             CAPITA    23183093    23183093_202402  35724945G5
# 3             CAPITA  1043586626  1043586626_202401  13854875G5
# 4             CAPITA    72073242    72073242_202401  13854875G5
#
#    cantidad_dispensada  costcomp_unit  valorventa_unit_sl  \
# 0                 60.0         32.384           40.000000
# 1                 30.0         39.468           55.384615
# ...

# %%
# Asegurarte de que ambas columnas id_paciente sean del mismo tipo
data['id_paciente'] = data['id_paciente'].astype(str)
df['id_paciente'] = df['id_paciente'].astype(str)

# %%
# Comparar y contar cuántos id_paciente coinciden
coincidencias = data['id_paciente'].isin(df['id_paciente'])

# Contar el número de coincidencias
numero_coincidencias = coincidencias.sum()

# Mostrar el resultado
print(f"Número de id_paciente que coinciden entre las dos tablas: {numero_coincidencias}")
# Out:
# Número de id_paciente que coinciden entre las dos tablas: 579384

# %%
# Obtener los id_paciente que coinciden
id_pacientes_coincidentes = data[data['id_paciente'].isin(df['id_paciente'])]['id_paciente']

# Mostrar los id_paciente coincidentes
print(id_pacientes_coincidentes)
# Out:
# 0         1002023082
# 1           72158665
# 2           23183093
# 3         1043586626
# 4           72073242
#              ...
# 585922      22662255
# 585923    1041891957
# 585924      22664466
# 585925    1043025830
# 585926      22473086
# Name: id_paciente, Length: 579384, dtype: object
